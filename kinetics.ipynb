# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as tck
# Instalar las librerias:
# pip install matplotlib pandas
# python -m pip <librerias> En linux
# py -m pip <librerias> En Windows


# Archivo a abrir, tiene que estar en la misma carpeta que el .ipynb
file_name = 'cinetica_Asp-2TS.csv' # The file in this directory

# Lee el archivo como un archivo de datos pandas. Leer documentación para más.
data = pd.read_csv(file_name, delimiter=';')


# Colores, puedes poner el hexadecimal '#000000' (negro) o 'black' 
axis_color = 'black'
data_color = '#1f77b4' # Blue
data_color2 = 'red'

# No se que hace pero ponlo
fig, ax = plt.subplots()
# minor stiks 
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())
ax.xaxis.set_minor_locator(tck.AutoMinorLocator())

# Así es como se ponen las columnas en pandas. data.iloc[:,0] = columna 0
#x = data.iloc[:,0]
#y1 = data.iloc[:,1]
#y2 = data.iloc[:,2]

# Asi se representan las gráficas
# ax.plot(x, y, linestyle='', marker='', markersize='', color='', label='')
ax.plot(data.iloc[:,0], data.iloc[:,1], linestyle='-', marker='D', markevery=9, markersize=4, color='#80ACA3', label='4 ºC [Asp-dNHS]')
ax.plot(data.iloc[:,0], data.iloc[:,2], linestyle='-', marker='s', markevery=9, markersize=4, color='#80ACA3', label='4 ºC [Asp-OSi]')

ax.plot(data.iloc[:,0], data.iloc[:,3], linestyle='-', marker='v', markevery=9, markersize=5, color='#88b984', label='21 ºC [Asp-dNHS]')
ax.plot(data.iloc[:,0], data.iloc[:,4], linestyle='-', marker='^', markevery=9, markersize=5, color='#88b984', label='21 ºC [Asp-OSi]')

ax.plot(data.iloc[:,0], data.iloc[:,5], linestyle='-', marker='*', markevery=9, markersize=7, color='#008080', label='30 ºC [Asp-dNHS]')
ax.plot(data.iloc[:,0], data.iloc[:,6], linestyle='-', marker='.', markevery=9, markersize=7, color='#008080', label='30 ºC [Asp-OSi]')

#ax.plot(data.iloc[:,7], data.iloc[:,8], linestyle='-', marker='s', markevery=9, markersize=4, color='#F9A686', label='4 ºC [Glu-dNHS]')
#ax.plot(data.iloc[:,7], data.iloc[:,9], linestyle='-', marker='s', markevery=9, markersize=4, color='#F9A686', label='4 ºC [Glu-OSi]')

#ax.plot(data.iloc[:,7], data.iloc[:,10], linestyle='-', marker='^', markevery=9, markersize=5, color='#f68060', label='21 ºC [Glu-dNHS]')
#ax.plot(data.iloc[:,7], data.iloc[:,11], linestyle='-', marker='^', markevery=9, markersize=5, color='#f68060', label='21 ºC [Glu-OSi]')

#ax.plot(data.iloc[:,7], data.iloc[:,12], linestyle='-', marker='.', markevery=9, markersize=7, color='#FB6F6F', label='30 ºC [Glu-dNHS]')
#ax.plot(data.iloc[:,7], data.iloc[:,13], linestyle='-', marker='.', markevery=9, markersize=7, color='#FB6F6F', label='30 ºC [Glu-OSi]')


# Primer valor de la primera columna y último valor de la primera columna
x1 = (data.iloc[:,1][0])
x2 = (data.iloc[:,1][len(data.iloc[:,0]) - 1])

y1 = (data.iloc[:,2][0])
y2 = (data.iloc[:,2][len(data.iloc[:,2]) - 1])

# Se puede escribir así y da menos miedo
columna = data.iloc[:,1]
x1 = (columna[1])
x2 = (columna[len(columna) - 1])

columna = data.iloc[:,2]
y1 = (columna[2])
y2 = (columna[len(columna) - 1])


# Pones los límites del gráfico
ax.set_xlim(0, 7170)
ax.set_ylim(0, 10)

# Aspect ratio, (x/y)/(aspect/ratio) si queremos un aspect ratio de 16:9
# 1. Calculamos la diferencia entre los limites en x (671 - 1) y lo multiplicamos por 9
# 2. Calculamos la diferencia entre los limites en y (67 - -40) y lo multiplicamos por 16
# (670/107)/(16/9). Para más información, la documentación.
ax.set_aspect((7171/10)/(16/9))

# Para las etiquetas 
ax.set_xlabel('t (fs)', color=axis_color)
#ax.set_xlabel(data.columns[0], color=axis_color)
ax.set_ylabel('[Concentration]', color=axis_color)
ax.legend(frameon=False)

# Cuadricula
#plt.grid()

fig.savefig("Asp-Temperature.svg")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some data
x = np.linspace(0, 10, 100)  # Original x values
y = np.sin(x)  # Original y values

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the original line
ax.plot(x, y, label='Original Line')

# Elongate the line by extending the x values
x_extended = np.linspace(0, 15, 150)  # New x values (elongated)
y_extended = np.sin(x_extended)  # New y values

# Plot the elongated line
ax.plot(x_extended, y_extended, label='Elongated Line', linestyle='--')

# Set the limits of the axes
ax.set_xlim(0, 15)  # Extend x-axis limit
ax.set_ylim(-1.5, 1.5)  # Adjust y-axis limit if necessary

# Add labels and legend
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Elongated Graph Line Example')
ax.legend()

# Show the plot
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some data
x = np.linspace(0, 10, 100)  # Original x values
y = np.sin(x)  # Original y values

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the original line
ax.plot(x, y, label='Sine Wave')

# Set the limits of the axes
ax.set_xlim(0, 10)
ax.set_ylim(-1.5, 1.5)

# Set the aspect ratio to stretch the graph
ax.set_aspect(2)  # Change this value to stretch more or less

# Add labels and legend
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Stretched Graph Example')
ax.legend()

# Show the plot
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.collections import EventCollection

# Fixing random state for reproducibility
np.random.seed(19680801)

# create random data
xdata = np.random.random([2, 10])

# split the data into two parts
xdata1 = xdata[0, :]
xdata2 = xdata[1, :]

# sort the data so it makes clean curves
xdata1.sort()
xdata2.sort()

# create some y data points
ydata1 = xdata1 ** 2
ydata2 = 1 - xdata2 ** 3

# plot the data
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(xdata1, ydata1, color='tab:blue')
ax.plot(xdata2, ydata2, color='tab:orange')

# create the events marking the x data points
xevents1 = EventCollection(xdata1, color='tab:blue', linelength=0.05)
xevents2 = EventCollection(xdata2, color='tab:orange', linelength=0.05)

# create the events marking the y data points
yevents1 = EventCollection(ydata1, color='tab:blue', linelength=0.05,
                           orientation='vertical')
yevents2 = EventCollection(ydata2, color='tab:orange', linelength=0.05,
                           orientation='vertical')

# add the events to the axis
ax.add_collection(xevents1)
ax.add_collection(xevents2)
ax.add_collection(yevents1)
ax.add_collection(yevents2)

# set the limits
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])

ax.set_title('line plot with data points')

# display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some data
x = np.linspace(0, 10, 100)  # Original x values
y = np.sin(x)  # Original y values

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the original line
ax.plot(x, y, label='Sine Wave')

# Set the limits of the axes
ax.set_xlim(0, 10)
ax.set_ylim(-1.5, 1.5)

# Set the aspect ratio to stretch the graph
ax.set_aspect(2)  # Change this value to stretch more or less

# Add labels and legend
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Stretched Graph Example')
ax.legend()

# Show the plot
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar algunos datos
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Crear una figura y un eje
fig, ax = plt.subplots()

# Graficar la línea
ax.plot(x, y, label='Seno')

# Ocultar los bordes
ax.spines['top'].set_visible(False)    # Ocultar el borde superior
ax.spines['right'].set_visible(False)  # Ocultar el borde derecho
ax.spines['left'].set_visible(False)   # Ocultar el borde izquierdo
ax.spines['bottom'].set_visible(False) # Ocultar el borde inferior

# Opcional: ajustar los ticks
ax.xaxis.set_ticks([])  # Ocultar los ticks del eje x
ax.yaxis.set_ticks([])  # Ocultar los ticks del eje y

# Añadir etiquetas y título
ax.set_title('Gráfica sin bordes')
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.legend()

# Mostrar la gráfica
plt.grid()
plt.show()
